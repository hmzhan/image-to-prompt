# %%
# !git clone --single-branch --branch feature/add_transformers https://github.com/OFA-Sys/OFA.git
# !pip wheel /kaggle/working/OFA/transformers/

# !git lfs install
# !git clone https://huggingface.co/OFA-Sys/OFA-large-caption
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Cloning into 'OFA'...
# remote: Enumerating objects: 5745, done.
# remote: Counting objects: 100% (559/559), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 5745 (delta 463), reused 435 (delta 435), pack-reused 5186
# Receiving objects: 100% (5745/5745), 97.77 MiB | 22.38 MiB/s, done.
# Resolving deltas: 100% (2236/2236), done.
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Processing ./OFA/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy>=1.17
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 46.0 MB/s eta 0:00:0000:0100:01
# Collecting packaging>=20.0
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 4.0 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.13.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.4 MB/s eta 0:00:00:00:0100:01
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 45.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tqdm>=4.27
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.5 MB/s eta 0:00:00
# Collecting importlib-metadata
#   Downloading importlib_metadata-6.3.0-py3-none-any.whl (22 kB)
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.3 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 14.0 MB/s eta 0:00:00
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 36.7 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.1/757.1 kB 36.2 MB/s eta 0:00:00
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 13.4 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.0/171.0 kB 13.1 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 13.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 5.2 MB/s eta 0:00:00
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 9.8 MB/s eta 0:00:00
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 21.9 MB/s eta 0:00:00
# Saved ./huggingface_hub-0.13.4-py3-none-any.whl
# Saved ./numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Saved ./packaging-23.1-py3-none-any.whl
# Saved ./PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Saved ./regex-2022.10.31-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./tokenizers-0.13.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./tqdm-4.65.0-py3-none-any.whl
# Saved ./filelock-3.11.0-py3-none-any.whl
# Saved ./importlib_metadata-6.3.0-py3-none-any.whl
# Saved ./requests-2.28.2-py3-none-any.whl
# Saved ./certifi-2022.12.7-py3-none-any.whl
# Saved ./charset_normalizer-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./idna-3.4-py3-none-any.whl
# Saved ./typing_extensions-4.5.0-py3-none-any.whl
# Saved ./urllib3-1.26.15-py2.py3-none-any.whl
# Saved ./zipp-3.15.0-py3-none-any.whl
# Saved ./click-8.1.3-py3-none-any.whl
# Saved ./joblib-1.2.0-py3-none-any.whl
# Saved ./six-1.16.0-py2.py3-none-any.whl
# Building wheels for collected packages: transformers, sacremoses
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.18.0.dev0-py3-none-any.whl size=3916764 sha256=8e2f2e1c9b0e3cf83e38c71c7571dbec7cd5f24106b70e6437449f93942d2402
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ueejwb0x/wheels/cb/f6/3c/85a6ef1056f699980a788a7ceb0d7f28520a17be83f89aa6de
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=c5e34438c00a97bf62fa4e64faf23f5b79ac0b1f7734192e4bc9db5d80ce3d83
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built transformers sacremoses
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Error: Failed to call git rev-parse --git-dir: exit status 128
# Git LFS initialized.
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Cloning into 'OFA-large-caption'...
# remote: Enumerating objects: 18, done.
# remote: Total 18 (delta 0), reused 0 (delta 0), pack-reused 18
# Unpacking objects: 100% (18/18), 537.51 KiB | 2.57 MiB/s, done.

# %%
# !git clone --single-branch --branch feature/add_transformers https://github.com/OFA-Sys/OFA.git
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Cloning into 'OFA'...
# remote: Enumerating objects: 5745, done.
# remote: Counting objects: 100% (932/932), done.
# remote: Compressing objects: 100% (256/256), done.
# remote: Total 5745 (delta 710), reused 676 (delta 676), pack-reused 4813
# Receiving objects: 100% (5745/5745), 97.78 MiB | 27.80 MiB/s, done.
# Resolving deltas: 100% (2243/2243), done.

# %%
# !pip wheel /kaggle/working/OFA/transformers/
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Processing ./OFA/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 15.9 MB/s eta 0:00:0000:01
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.1/757.1 kB 46.9 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.13.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.9 MB/s eta 0:00:00:00:0100:01
# Collecting tqdm>=4.27
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.6 MB/s eta 0:00:00
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 48.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting importlib-metadata
#   Downloading importlib_metadata-6.4.1-py3-none-any.whl (22 kB)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 16.3 MB/s eta 0:00:00
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.9 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 4.0 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Collecting numpy>=1.17
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 53.3 MB/s eta 0:00:0000:0100:01
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.0/171.0 kB 17.2 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 14.6 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 11.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 5.1 MB/s eta 0:00:00
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 9.0 MB/s eta 0:00:00
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 25.3 MB/s eta 0:00:00
# Saved ./huggingface_hub-0.13.4-py3-none-any.whl
# Saved ./numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Saved ./packaging-23.1-py3-none-any.whl
# Saved ./PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Saved ./regex-2022.10.31-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./tokenizers-0.13.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./tqdm-4.65.0-py3-none-any.whl
# Saved ./filelock-3.11.0-py3-none-any.whl
# Saved ./importlib_metadata-6.4.1-py3-none-any.whl
# Saved ./requests-2.28.2-py3-none-any.whl
# Saved ./certifi-2022.12.7-py3-none-any.whl
# Saved ./charset_normalizer-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./idna-3.4-py3-none-any.whl
# Saved ./typing_extensions-4.5.0-py3-none-any.whl
# Saved ./urllib3-1.26.15-py2.py3-none-any.whl
# Saved ./zipp-3.15.0-py3-none-any.whl
# Saved ./click-8.1.3-py3-none-any.whl
# Saved ./joblib-1.2.0-py3-none-any.whl
# Saved ./six-1.16.0-py2.py3-none-any.whl
# Building wheels for collected packages: transformers, sacremoses
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.18.0.dev0-py3-none-any.whl size=3916764 sha256=ee94a40bbd03f1bf94dad94cbb5961edea82e77f96cd9ee9aeed21e0b5b9ca92
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gml8v_a3/wheels/cb/f6/3c/85a6ef1056f699980a788a7ceb0d7f28520a17be83f89aa6de
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=d1e0877f3996a4d8d5f9cc2252cec1bf89265af70b0c9b7eadbebbd0b45961ba
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built transformers sacremoses
